# %%
% load_ext autoreload
% autoreload 2
import time
import numpy as np
from Conceptors.standard import ConceptorNetwork
from test.benchmark import Benchmark
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tensorflow as tf
sess = tf.InteractiveSession()

# %%
p = []
p.append(Benchmark(delay=0, f=8.8342522).train_input)
#p.append(Benchmark(delay=0, f=9.8342522).train_input)
#p.append(Benchmark(fun='mackey').train_input)
p.append(Benchmark(delay=0, f=14.8342522).train_input)

# %%
reservoir_size = 500
washout = 500
conceptor_net = ConceptorNetwork(1, reservoir_size, washout=washout, prec=tf.float64, aperture=1300.)
sess.run(tf.global_variables_initializer())

# %%
conceptor_net.load_patterns(p, sess)

# %%
_, predictions = conceptor_net.autonomous_run(1, 200, sess)
plt.plot(predictions[:200])

# %%
plt.plot(p[0][:200])

# %%
a,b = [(i[0],i[1]) for i in [(1,2),(3,4),(5,6)]]
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-fca4e9bf4e7f> in <module>()
# ----> 1 a,b = [(i[0],i[1]) for i in [(1,2),(3,4),(5,6)]]
#       2 a
#
# ValueError: too many values to unpack (expected 2)
